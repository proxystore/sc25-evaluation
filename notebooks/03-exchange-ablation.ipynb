# %%
from __future__ import annotations

import pathlib

import polars
import seaborn
from matplotlib import pyplot as plt

_ = polars.Config.set_tbl_rows(100)

# %%
def load_data(
    filepaths: list[tuple[str, str, pathlib.Path]],
) -> polars.DataFrame:
    dfs = []
    for scenario, label, filepath in filepaths:
        df = polars.read_csv(filepath)
        df = df.with_columns(
            polars.lit(scenario).alias('scenario'),
            polars.lit(label).alias('label'),
        )
        dfs.append(df)
    return polars.concat(dfs).sort(
        'label',
        'exchange',
        'proxystore',
        'data_size_bytes',
    )

# %%
local_runs = pathlib.Path('../data/bench/exchange-perf-local-v2/')
remote_runs = pathlib.Path('../data/bench/exchange-perf-remote-v2/')
filepaths = [
    ('local', 'Baseline', local_runs / '2025-04-05-21-38-05/results.csv'),
    ('local', '+Pass-by-ref', local_runs / '2025-04-05-21-43-27/results.csv'),
    ('local', '+Direct', local_runs / '2025-04-05-21-44-29/results.csv'),
    (
        'remote',
        '+Pass-by-ref',
        remote_runs / '2025-10-07-10-37-26/results.csv',
    ),
    ('remote', 'Baseline', remote_runs / '2025-10-08-10-32-27/results.csv'),
]
raw = load_data(filepaths)

# %%
raw
# Out:
# shape: (780, 6)
# ┌────────────────┬────────────┬─────────────────┬───────────┬──────────┬──────────┐
# │ exchange       ┆ proxystore ┆ data_size_bytes ┆ latency_s ┆ scenario ┆ label    │
# │ ---            ┆ ---        ┆ ---             ┆ ---       ┆ ---      ┆ ---      │
# │ str            ┆ bool       ┆ i64             ┆ f64       ┆ str      ┆ str      │
# ╞════════════════╪════════════╪═════════════════╪═══════════╪══════════╪══════════╡
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.065142  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.001896  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.001788  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.001852  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.001861  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.001675  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.00155   ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.001828  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.002143  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000            ┆ 0.042129  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.001941  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.00183   ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.002076  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.00196   ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.001923  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.001896  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.002071  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.001803  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.002473  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000           ┆ 0.001904  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.002015  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.002454  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.002692  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.002013  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.001976  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.001886  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.002024  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.001832  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.001839  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 100000          ┆ 0.001448  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.004476  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.003865  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.005179  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.003905  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.00346   ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.003975  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.003819  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.003552  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.003545  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 1000000         ┆ 0.003514  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.027662  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.033752  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.030735  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.029356  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.028426  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.027156  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.027211  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.028074  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.027654  ┆ local    ┆ +Direct  │
# │ HybridExchange ┆ false      ┆ 10000000        ┆ 0.028182  ┆ local    ┆ +Direct  │
# │ …              ┆ …          ┆ …               ┆ …         ┆ …        ┆ …        │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.171782  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.175286  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.176211  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.175572  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.172324  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.189233  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.166718  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.197157  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.166459  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000           ┆ 0.176371  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.465129  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.22898   ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.165117  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.167757  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.198149  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.165818  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.198193  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.199828  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.165253  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000          ┆ 0.168215  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.471407  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.258372  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.31972   ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.290047  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.262375  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.262956  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.260061  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.258382  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.258781  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 1000000         ┆ 0.261568  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.302996  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.351801  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.341752  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.3491    ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.284776  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.381725  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.378287  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.371014  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.373507  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 10000000        ┆ 1.306507  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 11.238832 ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 10.550017 ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 10.888126 ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 11.518694 ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 10.46871  ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 14.891042 ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 12.633688 ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 10.560599 ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 10.431148 ┆ local    ┆ Baseline │
# │ RedisExchange  ┆ false      ┆ 100000000       ┆ 10.60893  ┆ local    ┆ Baseline │
# └────────────────┴────────────┴─────────────────┴───────────┴──────────┴──────────┘

# %%
fig, axs = plt.subplots(1, 2, sharey=True)

data = raw.filter(polars.col('data_size_bytes') >= 10_000)
local_data = data.filter(polars.col('scenario') == 'local')
remote_data = data.filter(polars.col('scenario') == 'remote')

xticks = sorted(set(data['data_size_bytes'].to_list()))
xtick_labels = ['10 KB', '100 KB', '1 MB', '10 MB', '100 MB']
yticks = [0.001, 0.01, 0.1, 1, 10, 100]

hue_order = ['Baseline', '+Pass-by-ref', '+Direct']
palette = {
    'Baseline': '#4D3886',
    '+Pass-by-ref': '#D64269',
    '+Direct': '#3969AC',
}
markers = {
    'Baseline': 'o',
    '+Pass-by-ref': 'X',
    '+Direct': 'd',
}
dashes = {'+Direct': (2, 2), '+Pass-by-ref': (1, 1), 'Baseline': ()}

handle = seaborn.lineplot(
    local_data,
    x='data_size_bytes',
    y='latency_s',
    hue='label',
    hue_order=hue_order,
    errorbar='sd',
    style='label',
    dashes=dashes,
    markers=markers,
    palette=palette,
    ax=axs[0],
)
axs[0].set_title('Aurora → Aurora')
_ = handle.set(
    xscale='log',
    yscale='log',
    xlabel='Action Payload Size',
    ylabel='Action Latency (s)',
)
handle.set_xticks(xticks, minor=False)
handle.set_xticklabels(xtick_labels)
axs[0].tick_params(axis='x', which='minor', bottom=False)

handle = seaborn.lineplot(
    remote_data,
    x='data_size_bytes',
    y='latency_s',
    hue='label',
    hue_order=hue_order,
    errorbar='sd',
    style='label',
    dashes=dashes,
    markers=markers,
    palette=palette,
    ax=axs[1],
)
axs[1].set_title('Workstation → Aurora')
handles, _ = axs[0].get_legend_handles_labels()
axs[0].legend(
    loc='upper left',
    handles=handles,
    title=None,
)
axs[1].get_legend().remove()

_ = handle.set(
    xscale='log',
    yscale='log',
    xlabel='Action Payload Size',
    ylabel='Action Latency (s)',
)
handle.set_yticks(yticks, minor=False)
handle.set_yticklabels([str(y) for y in yticks])
handle.set_xticks(xticks, minor=False)
handle.set_xticklabels(xtick_labels)
axs[1].tick_params(axis='x', which='minor', bottom=False)

axs[0].set(ylim=[0.0009, 300])
for ax in axs:
    ax.set(xlim=[4_000, 300_000_000])
fig.subplots_adjust(wspace=2)

axs[1].annotate(
    'Lower is better\nError bands are std dev',
    xy=(0.98, 0.02),
    xycoords=('axes fraction'),
    ha='right',
    va='bottom',
)

fig.tight_layout()
plt.draw()
fig.set_size_inches(3.5, 1)
fig.savefig('figures/exchange-ablation.pdf')

# %%
raw.group_by(
    'label',
    'scenario',
    'exchange',
    'proxystore',
    'data_size_bytes',
    maintain_order=True,
).mean()
# Out:
# shape: (30, 6)
# ┌──────────────┬──────────┬─────────────────────┬────────────┬─────────────────┬───────────┐
# │ label        ┆ scenario ┆ exchange            ┆ proxystore ┆ data_size_bytes ┆ latency_s │
# │ ---          ┆ ---      ┆ ---                 ┆ ---        ┆ ---             ┆ ---       │
# │ str          ┆ str      ┆ str                 ┆ bool       ┆ i64             ┆ f64       │
# ╞══════════════╪══════════╪═════════════════════╪════════════╪═════════════════╪═══════════╡
# │ +Direct      ┆ local    ┆ HybridExchange      ┆ false      ┆ 1000            ┆ 0.012186  │
# │ +Direct      ┆ local    ┆ HybridExchange      ┆ false      ┆ 10000           ┆ 0.001988  │
# │ +Direct      ┆ local    ┆ HybridExchange      ┆ false      ┆ 100000          ┆ 0.002018  │
# │ +Direct      ┆ local    ┆ HybridExchange      ┆ false      ┆ 1000000         ┆ 0.003929  │
# │ +Direct      ┆ local    ┆ HybridExchange      ┆ false      ┆ 10000000        ┆ 0.028821  │
# │ +Direct      ┆ local    ┆ HybridExchange      ┆ false      ┆ 100000000       ┆ 0.272674  │
# │ +Pass-by-ref ┆ remote   ┆ HttpExchangeFactory ┆ true       ┆ 1000            ┆ 0.059776  │
# │ +Pass-by-ref ┆ remote   ┆ HttpExchangeFactory ┆ true       ┆ 10000           ┆ 0.066512  │
# │ +Pass-by-ref ┆ remote   ┆ HttpExchangeFactory ┆ true       ┆ 100000          ┆ 0.080034  │
# │ +Pass-by-ref ┆ remote   ┆ HttpExchangeFactory ┆ true       ┆ 1000000         ┆ 0.199783  │
# │ +Pass-by-ref ┆ remote   ┆ HttpExchangeFactory ┆ true       ┆ 10000000        ┆ 1.25351   │
# │ +Pass-by-ref ┆ remote   ┆ HttpExchangeFactory ┆ true       ┆ 100000000       ┆ 12.221854 │
# │ +Pass-by-ref ┆ local    ┆ RedisExchange       ┆ true       ┆ 1000            ┆ 0.192983  │
# │ +Pass-by-ref ┆ local    ┆ RedisExchange       ┆ true       ┆ 10000           ┆ 0.188065  │
# │ +Pass-by-ref ┆ local    ┆ RedisExchange       ┆ true       ┆ 100000          ┆ 0.187621  │
# │ +Pass-by-ref ┆ local    ┆ RedisExchange       ┆ true       ┆ 1000000         ┆ 0.188108  │
# │ +Pass-by-ref ┆ local    ┆ RedisExchange       ┆ true       ┆ 10000000        ┆ 0.219129  │
# │ +Pass-by-ref ┆ local    ┆ RedisExchange       ┆ true       ┆ 100000000       ┆ 1.006512  │
# │ Baseline     ┆ remote   ┆ HttpExchangeFactory ┆ false      ┆ 1000            ┆ 0.034815  │
# │ Baseline     ┆ remote   ┆ HttpExchangeFactory ┆ false      ┆ 10000           ┆ 0.035781  │
# │ Baseline     ┆ remote   ┆ HttpExchangeFactory ┆ false      ┆ 100000          ┆ 0.048148  │
# │ Baseline     ┆ remote   ┆ HttpExchangeFactory ┆ false      ┆ 1000000         ┆ 0.307776  │
# │ Baseline     ┆ remote   ┆ HttpExchangeFactory ┆ false      ┆ 10000000        ┆ 2.064685  │
# │ Baseline     ┆ remote   ┆ HttpExchangeFactory ┆ false      ┆ 100000000       ┆ 20.718635 │
# │ Baseline     ┆ local    ┆ RedisExchange       ┆ false      ┆ 1000            ┆ 0.182681  │
# │ Baseline     ┆ local    ┆ RedisExchange       ┆ false      ┆ 10000           ┆ 0.176711  │
# │ Baseline     ┆ local    ┆ RedisExchange       ┆ false      ┆ 100000          ┆ 0.212244  │
# │ Baseline     ┆ local    ┆ RedisExchange       ┆ false      ┆ 1000000         ┆ 0.290367  │
# │ Baseline     ┆ local    ┆ RedisExchange       ┆ false      ┆ 10000000        ┆ 1.344146  │
# │ Baseline     ┆ local    ┆ RedisExchange       ┆ false      ┆ 100000000       ┆ 11.378978 │
# └──────────────┴──────────┴─────────────────────┴────────────┴─────────────────┴───────────┘

# %%
1 - (11.378978/20.718635)
# Out:
# 0.4507853437255881
