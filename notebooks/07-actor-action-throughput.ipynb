# %%
from __future__ import annotations

import pathlib

import polars
import seaborn
from matplotlib import pyplot as plt

_ = polars.Config.set_tbl_rows(100)

# %%
def load_data(directory: pathlib.Path) -> polars.DataFrame:
    dfs = []
    for run in directory.glob('**/results.csv'):
        try:
            df = polars.read_csv(run)
            if len(df) > 0:
                dfs.append(df)
        except Exception as e:
            print(f'Error loading {run}... skipping: {e}')
    return polars.concat(dfs)

# %%
data = load_data(pathlib.Path('../data/bench/action-throughput-v1/')).sort(
    'framework',
    'num_actors',
)

# %%
fig, axs = plt.subplots(1, 1)

results = data.with_columns(
    (
        polars.col('num_actors')
        * polars.col('actions_per_actor')
        / polars.col('runtime')
    ).alias('throughput'),
)
print(results)

xticks = sorted(set(results['num_actors'].to_list()))
yticks = [10, 100, 1000, 10000]
yticklabels = ['10', '100', '1K', '10K']

dashes = {'ray': (2, 2), 'dask': (1, 1), 'academy': ()}
markers = {'ray': 'd', 'dask': 'X', 'academy': 'o'}
palette = {'ray': '#3969AC', 'dask': '#D64269', 'academy': '#4D3886'}

handle = seaborn.lineplot(
    results,
    x='num_actors',
    y='throughput',
    hue='framework',
    hue_order=['ray', 'dask', 'academy'],
    style='framework',
    dashes=dashes,
    markers=markers,
    palette=palette,
    ax=axs,
)
handles, _ = axs.get_legend_handles_labels()
axs.legend(
    loc='lower left',
    handles=handles[::-1],
    title=None,
    labels=['Academy', 'Dask', 'Ray'],
)
_ = handle.set(
    xscale='log',
    yscale='log',
    xlabel='Agents/Actors',
    ylabel='Action Throughput ($s^{-1}$)',
)
handle.set_xticks(xticks, minor=False)
handle.set_xticklabels([str(x) for x in xticks])
handle.set_yticks(yticks, minor=False)
handle.set_yticklabels([str(y) for y in yticklabels])
axs.tick_params(axis='x', which='minor', bottom=False)
axs.tick_params(axis='y', which='minor', bottom=False)
axs.set(ylim=[2, 40000])

axs.annotate(
    'Higher is better\n52 workers per node',
    xy=(0.98, 0.02),
    xycoords=('axes fraction'),
    ha='right',
    va='bottom',
)

fig.tight_layout()
plt.draw()
fig.set_size_inches(3.5, 1.15)
fig.savefig('figures/actor-action-throughput.pdf')
# Out:
# shape: (21, 7)
# ┌───────────┬────────────────┬───────────┬────────────────┬────────────┬────────────┬──────────────┐
# │ framework ┆ actions_per_ac ┆ num_nodes ┆ num_workers_pe ┆ num_actors ┆ runtime    ┆ throughput   │
# │ ---       ┆ tor            ┆ ---       ┆ r_node         ┆ ---        ┆ ---        ┆ ---          │
# │ str       ┆ ---            ┆ i64       ┆ ---            ┆ i64        ┆ f64        ┆ f64          │
# │           ┆ i64            ┆           ┆ i64            ┆            ┆            ┆              │
# ╞═══════════╪════════════════╪═══════════╪════════════════╪════════════╪════════════╪══════════════╡
# │ academy   ┆ 100            ┆ 1         ┆ 52             ┆ 52         ┆ 1.463471   ┆ 3553.197651  │
# │ academy   ┆ 100            ┆ 2         ┆ 52             ┆ 104        ┆ 3.054628   ┆ 3404.669396  │
# │ academy   ┆ 100            ┆ 4         ┆ 52             ┆ 208        ┆ 6.130314   ┆ 3392.974456  │
# │ academy   ┆ 100            ┆ 8         ┆ 52             ┆ 416        ┆ 11.573786  ┆ 3594.329568  │
# │ academy   ┆ 100            ┆ 16        ┆ 52             ┆ 832        ┆ 23.334325  ┆ 3565.562721  │
# │ academy   ┆ 100            ┆ 32        ┆ 52             ┆ 1664       ┆ 46.671939  ┆ 3565.311457  │
# │ academy   ┆ 100            ┆ 64        ┆ 52             ┆ 3328       ┆ 93.132063  ┆ 3573.420245  │
# │ dask      ┆ 100            ┆ 1         ┆ 52             ┆ 52         ┆ 18.580084  ┆ 279.869563   │
# │ dask      ┆ 100            ┆ 2         ┆ 52             ┆ 104        ┆ 50.161907  ┆ 207.328642   │
# │ dask      ┆ 100            ┆ 4         ┆ 52             ┆ 208        ┆ 112.307594 ┆ 185.205642   │
# │ dask      ┆ 100            ┆ 8         ┆ 52             ┆ 416        ┆ 228.519446 ┆ 182.0414     │
# │ dask      ┆ 100            ┆ 16        ┆ 52             ┆ 832        ┆ 464.376183 ┆ 179.165089   │
# │ dask      ┆ 100            ┆ 32        ┆ 52             ┆ 1664       ┆ 929.211845 ┆ 179.076495   │
# │ dask      ┆ 100            ┆ 64        ┆ 52             ┆ 3328       ┆ 2056.86645 ┆ 161.799518   │
# │ ray       ┆ 100            ┆ 1         ┆ 52             ┆ 52         ┆ 0.318433   ┆ 16329.951494 │
# │ ray       ┆ 100            ┆ 2         ┆ 52             ┆ 104        ┆ 0.588787   ┆ 17663.421196 │
# │ ray       ┆ 100            ┆ 4         ┆ 52             ┆ 208        ┆ 1.466699   ┆ 14181.509528 │
# │ ray       ┆ 100            ┆ 8         ┆ 52             ┆ 416        ┆ 2.984969   ┆ 13936.495272 │
# │ ray       ┆ 100            ┆ 16        ┆ 52             ┆ 832        ┆ 5.588456   ┆ 14887.833264 │
# │ ray       ┆ 100            ┆ 32        ┆ 52             ┆ 1664       ┆ 10.835973  ┆ 15356.257769 │
# │ ray       ┆ 100            ┆ 64        ┆ 52             ┆ 3328       ┆ 25.874284  ┆ 12862.19184  │
# └───────────┴────────────────┴───────────┴────────────────┴────────────┴────────────┴──────────────┘
