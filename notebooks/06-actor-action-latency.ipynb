# %%
from __future__ import annotations

import pathlib

import polars
import seaborn
from matplotlib import pyplot as plt

_ = polars.Config.set_tbl_rows(100)

# %%
def load_data(directory: pathlib.Path) -> polars.DataFrame:
    dfs = []
    for run in directory.glob('**/results.csv'):
        try:
            df = polars.read_csv(run)
            if len(df) > 0:
                dfs.append(df)
        except Exception as e:
            print(f'Error loading {run}... skipping: {e}')
    return polars.concat(dfs)

# %%
data = load_data(pathlib.Path('../data/bench/action-latency-v3/'))

# %%
results = data.filter(~polars.col('framework').str.contains('Redis'))
results = results.with_columns(
    polars.col('framework')
    .replace('Academy[HybridExchange]', 'Academy')
    .alias('framework'),
)
results
# Out:
# shape: (18, 5)
# ┌───────────┬────────┬─────────────────┬────────────────┬─────────────────┐
# │ framework ┆ trials ┆ data_size_bytes ┆ mean_latency_s ┆ stdev_latency_s │
# │ ---       ┆ ---    ┆ ---             ┆ ---            ┆ ---             │
# │ str       ┆ i64    ┆ i64             ┆ f64            ┆ f64             │
# ╞═══════════╪════════╪═════════════════╪════════════════╪═════════════════╡
# │ Dask      ┆ 50     ┆ 1000            ┆ 0.001186       ┆ 0.001059        │
# │ Dask      ┆ 50     ┆ 10000           ┆ 0.001508       ┆ 0.000076        │
# │ Dask      ┆ 50     ┆ 100000          ┆ 0.003356       ┆ 0.000411        │
# │ Dask      ┆ 50     ┆ 1000000         ┆ 0.020946       ┆ 0.000209        │
# │ Dask      ┆ 50     ┆ 10000000        ┆ 0.190148       ┆ 0.000579        │
# │ Dask      ┆ 50     ┆ 100000000       ┆ 1.8918         ┆ 0.005172        │
# │ Academy   ┆ 10     ┆ 1000            ┆ 0.000386       ┆ 0.000302        │
# │ Academy   ┆ 10     ┆ 10000           ┆ 0.000626       ┆ 0.000024        │
# │ Academy   ┆ 10     ┆ 100000          ┆ 0.00081        ┆ 0.000089        │
# │ Academy   ┆ 10     ┆ 1000000         ┆ 0.002483       ┆ 0.001089        │
# │ Academy   ┆ 10     ┆ 10000000        ┆ 0.023298       ┆ 0.004167        │
# │ Academy   ┆ 10     ┆ 100000000       ┆ 0.29636        ┆ 0.002004        │
# │ Ray       ┆ 50     ┆ 1000            ┆ 0.000526       ┆ 0.000308        │
# │ Ray       ┆ 50     ┆ 10000           ┆ 0.000483       ┆ 0.000056        │
# │ Ray       ┆ 50     ┆ 100000          ┆ 0.000896       ┆ 0.000061        │
# │ Ray       ┆ 50     ┆ 1000000         ┆ 0.007653       ┆ 0.002432        │
# │ Ray       ┆ 50     ┆ 10000000        ┆ 0.049091       ┆ 0.011363        │
# │ Ray       ┆ 50     ┆ 100000000       ┆ 0.317018       ┆ 0.022992        │
# └───────────┴────────┴─────────────────┴────────────────┴─────────────────┘

# %%
fig, axs = plt.subplots(1, 1)

xticks = sorted(set(results['data_size_bytes'].to_list()))
xtick_labels = ['1KB', '10 KB', '100 KB', '1 MB', '10 MB', '100 MB']
yticks = [0.0001, 0.001, 0.01, 0.1, 1]

dashes = {'Ray': (2, 2), 'Dask': (1, 1), 'Academy': ()}
markers = {'Ray': 'd', 'Dask': 'X', 'Academy': 'o'}
palette = {'Ray': '#3969AC', 'Dask': '#D64269', 'Academy': '#4D3886'}

handle = seaborn.lineplot(
    results,
    x='data_size_bytes',
    y='mean_latency_s',
    hue='framework',
    hue_order=['Ray', 'Dask', 'Academy'],
    style='framework',
    dashes=dashes,
    markers=markers,
    palette=palette,
    ax=axs,
)

for i, name in enumerate(['Ray', 'Dask', 'Academy']):
    subset = results.filter(polars.col('framework') == name)
    x = subset['data_size_bytes']
    y = subset['mean_latency_s']
    err = subset['stdev_latency_s']
    color = axs.get_lines()[i].get_c()

    lower = y - err
    upper = y + err
    axs.fill_between(x, lower, upper, alpha=0.2, color=color)


handles, _ = axs.get_legend_handles_labels()
axs.legend(
    handles=handles[::-1],
    title=None,
    labels=['Academy', 'Dask', 'Ray'],
)
_ = handle.set(
    xscale='log',
    yscale='log',
    xlabel='Action Payload Size',
    ylabel='Action Latency (s)',
)
handle.set_xticks(xticks, minor=False)
handle.set_xticklabels(xtick_labels)
axs.tick_params(axis='x', which='minor', bottom=False)
handle.set_yticks(yticks, minor=False)
handle.set_yticklabels([str(y) for y in yticks])

axs.annotate(
    'Lower is better\nError bands are std dev',
    xy=(0.98, 0.02),
    xycoords=('axes fraction'),
    ha='right',
    va='bottom',
)

fig.tight_layout()
plt.draw()
fig.set_size_inches(3.5, 1)
fig.savefig('figures/actor-action-latency.pdf')
